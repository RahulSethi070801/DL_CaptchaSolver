# %%
# !pip3 install captcha
# Out:
# Collecting captcha
#   Downloading captcha-0.3-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 4.5 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from captcha) (7.1.2)
# Installing collected packages: captcha
# Successfully installed captcha-0.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from io import BytesIO
from captcha.image import ImageCaptcha
import os
from random import randint
from tqdm import tqdm

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
# %cd DL_Project
# Out:
# /content/drive/MyDrive/DL_Project

# %%
folderName = 'Dataset/Alpha/SingleChar/'

# %%
ls
# Out:
# Dataset/  Notebooks/

# %%
fontPath = 'Dataset/ttf/'

# %%
fonts = [];
for file in os.listdir(fontPath):
    fonts.append(fontPath+file);
print(fonts)
image = ImageCaptcha(fonts=fonts)
# Out:
# ['Dataset/ttf/!The Black Bloc Bold Italic.ttf', 'Dataset/ttf/!The Black Bloc Bold.ttf', 'Dataset/ttf/!The Black Bloc Italic.ttf', 'Dataset/ttf/!The Black Bloc Regular.ttf', 'Dataset/ttf/08 Underground.ttf', 'Dataset/ttf/1942 Report.ttf', 'Dataset/ttf/36 Days Ago Bold.ttf', 'Dataset/ttf/36 Days Ago Regular.ttf', 'Dataset/ttf/50 Blizzards.ttf', 'Dataset/ttf/8 Bit Wonder.ttf', 'Dataset/ttf/A Dripping Marker.ttf', 'Dataset/ttf/Aaaiight! Bold.ttf', 'Dataset/ttf/Aaaiight! Regular.ttf', 'Dataset/ttf/Aardvark Cafe.ttf', 'Dataset/ttf/Adolphus Serif.ttf', 'Dataset/ttf/Adolphus.ttf', 'Dataset/ttf/African.ttf', 'Dataset/ttf/Agafont.ttf', 'Dataset/ttf/Airmole Antique.ttf', 'Dataset/ttf/Airmole Regular.ttf', 'Dataset/ttf/Airmole Shaded.ttf', 'Dataset/ttf/Airmole Stripe.ttf', 'Dataset/ttf/akaPosse.ttf', 'Dataset/ttf/Alanus.ttf', 'Dataset/ttf/Aldo.ttf', 'Dataset/ttf/All Hooked Up.ttf', 'Dataset/ttf/Almonte.ttf', 'Dataset/ttf/Alpha 54.ttf', 'Dataset/ttf/Alphabits Fat.ttf', 'Dataset/ttf/Alphabits Light.ttf', 'Dataset/ttf/Alphabits Regular.ttf', 'Dataset/ttf/Amerika Sans.ttf', 'Dataset/ttf/Antelope.ttf', 'Dataset/ttf/Arabolical.ttf', 'Dataset/ttf/Archeologicaps.ttf', 'Dataset/ttf/Architek.ttf', 'Dataset/ttf/Art Brush.ttf', 'Dataset/ttf/Artistica.ttf', 'Dataset/ttf/Astrud.ttf', 'Dataset/ttf/Augusta Shadow.ttf', 'Dataset/ttf/Augusta.ttf', 'Dataset/ttf/Averia Bold Italic.ttf
dataset/ttf/Cardinal.ttf', 'Dataset/ttf/Cargo Crate.ttf', 'Dataset/ttf/Cat Shop.ttf', 'Dataset/ttf/Chang  And Eng.ttf', 'Dataset/ttf/Chantelli Antiqua.ttf', 'Dataset/ttf/Chicago by Benj Funk.ttf', 'Dataset/ttf/Chinese Calligraphy.ttf', 'Dataset/ttf/Chisel Script.ttf', 'Dataset/ttf/Chow Fun.ttf', 'Dataset/ttf/Chrome Yellow.ttf', 'Dataset/ttf/Class A.ttf', 'Dataset/ttf/Cleopatra.ttf', 'Dataset/ttf/Cliff Edge.ttf', 'Dataset/ttf/Colourbars Bold.ttf', 'Dataset/ttf/Colourbars.ttf', 'Dataset/ttf/Concrete Shoes.ttf', 'Dataset/ttf/Corleone Due.ttf', 'Dataset/ttf/Corleone.ttf', 'Dataset/ttf/Corporate HQ.ttf', 'Dataset/ttf/Crack.ttf', 'Dataset/ttf/Crazy Crazy.ttf', 'Dataset/ttf/Credit River.ttf', 'Dataset/ttf/Crop Types.ttf', 'Dataset/ttf/Crystal Radio Kit.ttf', 'Dataset/ttf/Currency Regu ...

# %%
captchlength = 1;
numGenerate = 2000;
generatorDictionary = dict();
for i in tqdm(range(numGenerate)):
    #generate random number and convert to character
    sample = [randint(65,90) for x in range(captchlength)];
    #convert to charac6ters
    string = [chr(x) for x in sample];
    string = ''.join(string);
    # print(string)
    if(string not in generatorDictionary):
        generatorDictionary[string] = 0;
    generatorDictionary[string]+=1;
    data = image.generate(string)
    assert isinstance(data, BytesIO)

    ## before we write, we should check for duplicates, which there will be in the
    ## case we use a single char

    key = generatorDictionary[string];
    image.write(string, folderName+string+'_'+str(key)+'.png')
# Out:
# 100%|██████████| 2000/2000 [00:28<00:00, 70.17it/s]

# %%
path = 'D:\\Documents\\CS229\\Project\\Fonts\\'
database = 'D:\\Documents\\CS229\\Project\\SingleCharDatabase\\'
fonts = [];
for file in os.listdir(path):
    fonts.append(path+file);
print(fonts)
image = ImageCaptcha(fonts=fonts)

captchlength = 1;
numGenerate = 5000;
generatorDictionary = dict();
for i in range(numGenerate):
    #generate random number and convert to character
    sample = [randint(65,90) for x in range(captchlength)];
    #convert to charac6ters
    string = [chr(x) for x in sample];
    string = ''.join(string);
    print(string)
    if(string not in generatorDictionary):
        generatorDictionary[string] = 0;
    generatorDictionary[string]+=1;
    data = image.generate(string)
    assert isinstance(data, BytesIO)

    ## before we write, we should check for duplicates, which there will be in the
    ## case we use a single char

    key = generatorDictionary[string];
    image.write(string, database+string+'_'+str(key)+'.png')
