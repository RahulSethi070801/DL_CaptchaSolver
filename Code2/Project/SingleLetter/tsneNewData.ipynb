# %%
import numpy as np
from matplotlib import pyplot as plt
from tsne import bh_sne
import os
import torch
import pickle
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def loadPickleData(file):
    data = pickle.load(open(file, 'rb'));
    images = data[0];
    labels = data[1];
    return [images, labels]

# %%
pwd
# Out:
# '/media/data_dump/mann/Pritish/BTP/test/SingleLetter'

# %%
[images,labels] = loadPickleData("./../Data/pickledFiles/Num_NewData_1char_3channel.p")

# %%
images.shape
# Out:
# (5000, 60, 40, 3)

# %%
labels.shape
# Out:
# (5000,)

# %%
x_data = np.asarray(images).astype('float64')
x_data = x_data.reshape((x_data.shape[0], -1))
y_data = list(labels)

# %%
vis_data = bh_sne(x_data,perplexity=10)

# %%
vis_x = vis_data[:, 0]
vis_y = vis_data[:, 1]

# %%
type(y_data[0])
# Out:
# numpy.int64

# %%
plt.scatter(vis_x, vis_y, c=y_data)
plt.colorbar(ticks=range(10))
plt.clim(-0.5, 10.5)
plt.show()
